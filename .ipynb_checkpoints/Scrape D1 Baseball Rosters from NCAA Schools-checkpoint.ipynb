# %%
#ALL IMPORTS AND FUNCTIONS

from bs4 import BeautifulSoup
from pyvirtualdisplay import Display
import requests
import time
from datetime import datetime
import pandas as pd
import re
from requests import Session
from requests.exceptions import MissingSchema, InvalidURL, SSLError, RequestException, Timeout
import numpy as np

_HEADERS = {'User-Agent': 'Mozilla/5.0'}
base_ncaa_url = 'https://www.ncaa.com'
year = '2024'
prior_year = str(int(year) - 1)  #Prior year

# %%
def remove_leading_parts(list_of_urls):
    new_list = []
    for url in list_of_urls:
        index = url.find('.com/')
        if index != -1:
            new_url = url[index+4:]  # +4 because len('.com') is 4
            new_list.append(new_url)
        else:
            new_list.append(url)  # If '.com/' is not found, keep the original url
    return new_list

# FROM NCAA WEBSITE
def get_all_school_media_links():
    media_links_df = pd.DataFrame(columns=['school_name', 'official_school_website', 'twitter', 'facebook'])
    counter = 1
    #23 IS THE NUMBER OF PAGES IN SCHOOLS-INDEX
    while counter <= 23:
        ncaa_schools_url = base_ncaa_url+'/schools-index/'+str(counter)
        with Session() as s:
            r = s.get(ncaa_schools_url, headers=_HEADERS, timeout = 5)
        if r.status_code == 403:
            print('An error occurred with the GET Request')
            print('403 Error: blocked request')
            continue
        soup = BeautifulSoup(r.text, features='lxml')
        # Find all 'a' tags in the table
        table = soup.find('table', {'class': 'responsive-enabled'})
        links = table.find_all('a')
        # Extract the URLs and the school names from each 'a' tag
        urls_and_names = [(link.get('href'), link.text) for link in links]
        
        for url, name in urls_and_names:
            individual_school_url = base_ncaa_url+url
            with Session() as s:
                r = s.get(individual_school_url, headers=_HEADERS, timeout = 5)
            if r.status_code == 403:
                print('An error occurred with the GET Request')
                print('403 Error: blocked request')
            soup = BeautifulSoup(r.text, features='lxml')
            # Find all 'a' tags in the div
            div = soup.find('div', {'class': 'school-links'})
            if div is None:
                continue
            media_links = div.find_all('a')
        
            # Extract the URLs from the 'href' attribute of each 'a' tag
            media_urls = [media_link.get('href') for media_link in media_links]
            # Add the URLs and the school name to the DataFrame
            temp_df = pd.DataFrame({
                'school_name': [name],
                'official_school_website': [media_urls[0] if len(media_urls) > 0 else None],
                'twitter': [media_urls[1] if len(media_urls) > 1 else None],
                'facebook': [media_urls[2] if len(media_urls) > 2 else None]
            })
            if not name == '':
                print(f"got links for {name}")
                media_links_df = pd.concat([media_links_df, temp_df], ignore_index=True)
            
        counter+=1
        print(f"finished scraping page {counter}")
        # print(media_links_df.tail)
    
    # Drop duplicates after all pages have been processed
    media_links_df = media_links_df.drop_duplicates()
    return media_links_df

def get_player_name_from_player_bio(soup):
    try:
        name_span = soup.find('span', {'class': 'sidearm-roster-player-name'})
        
        # Try to find the first name span
        first_name_span = name_span.find('span', {'class': 'sidearm-roster-player-first-name'})
        if first_name_span is not None:
            first_name = first_name_span.text
        else:
            # Try something else if the first name span doesn't exist
            spans = name_span.find_all('span')
            first_name = spans[0].text if spans else ''
        
        # Try to find the last name span
        last_name_span = name_span.find('span', {'class': 'sidearm-roster-player-last-name'})
        if last_name_span is not None:
            last_name = last_name_span.text
        else:
            # Try something else if the last name span doesn't exist
            spans = name_span.find_all('span')
            last_name = spans[1].text if len(spans) > 1 else ''
        
        name = f"{first_name} {last_name}"
    
    except AttributeError:
        name = ''  # Handle missing name
    
    return name

def get_jersey_number_from_player_bio(soup):
    try:
        jersey_number_span = soup.find('span', {'class': 'sidearm-roster-player-jersey-number'})
        jersey_number_text = jersey_number_span.text.strip()
        # Use regex to find the first number in the text
        match = re.search(r'\d+', jersey_number_text)
        if match:
            jersey_number = match.group()  # The first number in the text
        else:
            jersey_number = ''  # No number found in the text
    except AttributeError:
        jersey_number = ''  # Handle missing jersey number
    return jersey_number

def get_miscellaneous_player_bio_data(soup):
    try:
        ul = soup.find('ul', {'class': 'flex flex-item-1 row flex-wrap'})
        dl_tags = ul.find_all('dl')
        headers = [tag.find('dt').text.rstrip(':') for tag in dl_tags]  # Remove colons
        data = [tag.find('dd').text for tag in dl_tags]
    except AttributeError:
        data = '' # Handle missing player bio info
    return headers, data


def get_social_media_link(soup):
    try:
        social_media_div = soup.find('div', {'class': 'sidearm-roster-player-social flex flex-wrap'})
        if social_media_div is not None:
            social_media_a = social_media_div.find('a', {'class': 'sidearm-roster-player-social-link'})
            if social_media_a is not None:
                social_media_link = social_media_a['href']
            else:
                social_media_link = ''  # Handle missing social media a tag
        else:
            social_media_link = ''  # Handle missing social media div
    except KeyError:
        social_media_link = ''  # Handle missing href attribute

    return social_media_link

def get_roster_soup(base_url, year, prior_year, _HEADERS):
    if base_url.startswith("http:"):
        base_url = base_url.replace("http:", "https:", 1)
    if base_url.endswith("/"):
        base_url = base_url[:-1]
    urls = [
        base_url+'/sports/baseball/roster/'+year,
        base_url+'/baseball/roster/'+year,
        base_url+'/sports/baseball/roster/',
        base_url+'/baseball/roster/',
        base_url+'/sport/m-basebl/roster/',
        base_url+'/sports/bsb/'+prior_year+'-'+year+'/roster'
    ]
    check_urls = [
        '/sports/baseball/roster/'+year,
        '/baseball/roster/'+year,
        '/sports/baseball/roster/',
        '/baseball/roster/',
        '/sport/m-basebl/roster/',
        '/sports/bsb/'+prior_year+'-'+year+'/roster'
    ]
    for url, check_url in zip(urls, check_urls):
        try:
            with Session() as s:
                r = s.get(url, headers=_HEADERS, timeout=5)
            if not r.url.endswith(check_url) and not r.url.endswith(check_url+'/'):  # If final URL does not end with check_url, a redirect occurred
                print('Redirect occurred for:', url,'Didnt match:', r.url)
                continue
            elif r.status_code == 404:
                print('404 Error')
                continue
            elif r.status_code == 403:
                print('An error occurred with the GET Request')
                print('403 Error: blocked request')
                continue
            elif r.status_code // 100 == 3:  # If status code is in 300s, it's a redirect
                print('Redirect occurred with the GET Request for URL:', url)
                continue 
            else:
                soup = BeautifulSoup(r.text, 'lxml')
                print(url)
                return soup
        except (MissingSchema, InvalidURL, SSLError, RequestException, Timeout) as e:
            print('Broken URL:', url)
            continue
    return None


def get_player_bio_links(soup):
    links = []
    for link in soup.find_all('a'):
        href = link.get('href')
        if href and '/roster/' in href:
            links.append(href)
    links = remove_leading_parts(links)
    return list(set(links)) 

def get_player_bio_soup(div, base_url, _HEADERS):
    a = div.find('a')
    if a is None:
        return None
    player_bio_url = base_url + a['href']
    try:
        with Session() as s:
            r = s.get(player_bio_url, headers=_HEADERS, timeout = 5)
        if r.status_code == 403:
            print('An error occurred with the GET Request')
            print('403 Error: blocked request')
            return None
    except (MissingSchema, InvalidURL, SSLError, RequestException, Timeout) as e:
        print('broken URL:', player_bio_url)
        return None
    soup = BeautifulSoup(r.text, features='lxml')
    return soup


#FUTURE WORK CAN REPLACE THIS WITH A FUNCTION
# with Session() as s:
#         r = s.get(player_bio_url, headers=_HEADERS)
#     if r.status_code == 403:
#         print('An error occurred with the GET Request')
#         print('403 Error: blocked request')
#         return None

#     soup = BeautifulSoup(r.text, features='lxml')

# %%
##START WITH DATAFRAME OF ALL SCHOOL SPORT WEBSITES AND SCRAPE PLAYER BIO DATA FOR ALL PLAYERS ON THAT ROSTER

# Start the timer
start_time = time.time()

#This comes from the script Get All D1 School Website URL's
official_websites = pd.read_csv('test_data/all_skipped_rosters_3_13.csv')
official_websites = official_websites.dropna(subset=['school_website_url'])
# test_websites = official_websites[official_websites['school_website_url']=='http://appstatesports.com']
# print(test_websites)

player_bio_df = pd.DataFrame()
skipped_rosters = []
skipped_players = []

#Loop through all schools on NCAA website and try a url to retrieve their roster
for index, base_url in enumerate(official_websites['school_website_url']):
# for index, base_url in enumerate(test_websites['school_website_url']):
    
    print(f"base_url: {base_url}")
    if base_url is None:
        print('skipped roster')
        skipped_rosters.append(base_url)
        continue
    roster_soup = get_roster_soup(base_url, year, prior_year, _HEADERS)
    if roster_soup is None:  
        print('skipped roster b/c roster page had no soup')
        skipped_rosters.append(base_url)
        continue    
    all_player_bio_links = get_player_bio_links(roster_soup)
    print(all_player_bio_links)

    # if len(roster_soup.find_all('div', {'class': 'sidearm-roster-player-image'})) == 0:
    #     print('skipped roster b/c there was no div class sidearm-roster-player-image')
    #     skipped_rosters.append(base_url)
    #     continue    
    # Need to do some sort of coalesce(
    #s-person-details__personal-single-line s-text-paragraph-bold flex items-center gap-2
    
    visited_bio_urls = set()
    
    for div in roster_soup.find_all('div', {'class': 'sidearm-roster-player-image'}):

        player_bio_soup, player_bio_url = get_player_bio_soup(div, base_url, _HEADERS)
        if player_bio_soup is None:
            print('skipped player b/c bio_soup returned none')
            skipped_players.append(player_bio_url)
            continue
        if player_bio_url in visited_bio_urls or 'roster/coaches/' in player_bio_url or '/roster/staff/' in player_bio_url:
            print('on to next roster')
            break
            
        print(f" Retrieving roster information from: {player_bio_url}")
        visited_bio_urls.add(player_bio_url)
        
        name = get_player_name_from_player_bio(player_bio_soup)
        if name == '':
            print('skipped player')
            skipped_players.append(player_bio_url)
            continue
        jersey_number = get_jersey_number_from_player_bio(player_bio_soup)
        social_media_link = get_social_media_link(player_bio_soup)
        headers, data = get_miscellaneous_player_bio_data(player_bio_soup)     
        
        player_data = {'Team': official_websites.loc[index, 'school'], 'Name': name, 'Jersey Number': jersey_number, 'Social Media': social_media_link}
        player_data.update(dict(zip(headers, data)))
        player_df = pd.DataFrame([player_data])      
        player_bio_df = pd.concat([player_bio_df, player_df], ignore_index=True, sort=False)

end_time = time.time()
print(f"Time taken: {end_time - start_time} seconds")


#MAKE SURE ALL SITES ARE SCRAPED. IF NOT SCRAPED FIND OUT WHY
#NEED TO SEE IF USING LIST METHOD GET_PLAYER_BIO_LINKS IS MORE SUITABLE THEN roster_soup.find_all('div', {'class': 'sidearm-roster-player-image'})
#MIGHT BE A COMBO OF THE TWO
    #Add check to ensure all rosters were successfully scraped
#IF ROSTER IS VALID BUT FOR SOME REASON SCRAPING DOESN'T WORK ADD TO A LIST TO KEEP REPEATING THROUGH UNTIL LIST COMPLETE
#NEED TO GRAB NAME & JERSEY NUMBER FROM NCAA.STATS TEAM PAGE TO MATCH WITH BOX SCORES


#CONSIDER SCRAPING DIRECTLY FROM ROSTER INSTEAD OF GOING TO INDIVIDUAL PLAYER BIOS
#CONSIDER MAKING THIS A GENERATOR FUNCTION EVENUTALLY
#NEED TO ADD TRANSFORMATION TO TIE TOGETHER ALL COLUMNS THAT ARE ACTUALLY THE SAME. (PARSE HT/WT TO SEPERATE COLUMNS, DELETE UNECESSARY COLUMNS, ADD URL'S TO SOCIAL MEDIA SITES)
#NEED TO CREATE PROPER KEY TO JOIN TO OTHER TABLES (REMOVE NICKNAMES LAWRENCE "Q" NOBLE) AND TURN INTO NOBLE, LAWRENCE
#IF JOIN BETWEEN NAMES IS NOT WORKING, CAN TRY TO GRAB JERSEY NUMBER FROM NCAA STATS AND JOIN ON THAT TO ROSTER+TEAM (MAY CREATE NEW TABLE OF ALL PLAYERS, JERSEY NUMBER AND WEBSITE NAME)
#REORGANIZE AND TURN INTO DIFFERENT FILES AND DEFINITIONS
#join box score stats to ncaa roster based on name and jersey number
    #ALTERNATIVELY CAN GRAB TEAM ID FROM NCAA OR TRY TO GET CORRECT JERSEY NUMBER FROM NCAA STATS
# Out:
# base_url: http://gozips.com
# https://gozips.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/dawson-tourney/8900', '/sports/baseball/roster/emmett-gillies/8762', '/sports/baseball/roster/james-strom/8907', '/sports/baseball/roster/ben-brombaugh/8901', '/sports/baseball/roster/spencer-atkins/8749', '/sports/baseball/roster/nicky-sackett/8903', '/sports/baseball/roster/michael-sprockett/8778', '/sports/baseball/roster/josiah-ross/8914', '/sports/baseball/roster/andrew-horvath/8764', '/sports/baseball/roster/michael-orlowski/8917', '/sports/baseball/roster/evan-bottone/8905', '/sports/baseball/roster/charlie-schebler/8896', '/sports/baseball/roster/jared-schaeffer/8918', '/sports/baseball/roster/yassir-kahook/8767', '/sports/baseball/roster/ryan-brown/8909', '/sports/baseball/roster/jack-poist/8773', '/sports/baseball/roster/anthony-fett/8759', '/sports/baseball/roster/reece-sutphin/8904', '/sports/baseball/roster/nick-kemper/8912', '/sports/baseball/roster/brett-dietrich/8757', '/sports/baseball/roster/jack-kelley/8916', '/sports/baseball/roster/fisher-pyatt/8915', '/sports/baseball/roster/elijah-griffith/8913', '/sports/baseball/roster/breydan-cavey/8755', '/sports/baseball/roster/charlie-rhee/8906', '/sports/baseball/roster/john-allen/8747', '/sports/baseball/roster/austin-lafferty/8898', '/sports/baseball/roster/max-bowman/8753', '/sports/baseball/roster/tre-rex/8895', '/sports/baseball/roster/parker-munday/8899', '/sports/baseball/roster/jacob-beall/8750', '/sports/baseball/roster/sean-perkins/8771', '/sports/baseball/roster/henry-hayman/8910', '/sports/baseball/roster/ian-pennington/8770', '/sports/baseball/roster/sam-seeker/8777']
# []
# base_url: http://www.12thman.com
# https://www.12thman.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/caden-sorrell/12443', '/sports/baseball/roster/brad-rudis/11834', '/sports/baseball/roster/brock-peery/12464', '/sports/baseball/roster/shane-sdao/11835', '/sports/baseball/roster/max-kaufer/11828', '/sports/baseball/roster/zach-frye/12530', '/sports/baseball/roster/kaiden-wilson/12451', '/sports/baseball/roster/justin-vossos/11841', '/sports/baseball/roster/ali-camarillo/12457', '/sports/baseball/roster/hayden-schott/12460', '/sports/baseball/roster/jackson-brasseux/12449', '/sports/baseball/roster/boots-landry/12447', '/sports/baseball/roster/tab-tracy/11839', '/sports/baseball/roster/ty-baker/12526', '/sports/baseball/roster/blake-binderup/11816', '/sports/baseball/roster/carl-schmidt/12444', '/sports/baseball/roster/jackson-appel/12459', '/sports/baseball/roster/ryan-prager/11833', '/sports/baseball/roster/chris-cortez/11818', '/sports/baseball/roster/gavin-grahovac/12442', '/sports/baseball/roster/austin-vargas/12455', '/sports/baseball/roster/evan-aschenbeck/12501', '/sports/baseball/roster/braden-montgomery/12456', '/sports/baseball/roster/kaeden-kent/11829', '/sports/baseball/roster/tanner-jones/12462', '/sports/baseball/roster/jack-bell/12445', '/sports/baseball/roster/ted-burton/12458', '/sports/baseball/roster/jett-johnston/12446', '/sports/baseball/roster/isaac-morton/12454', '/sports/baseball/roster/ryan-targac/11838', '/sports/baseball/roster/hank-bard/11815', '/sports/baseball/roster/troy-wansing/11842', '/sports/baseball/roster/peyton-smith/13830', '/sports/baseball/roster/jace-laviolette/11831', '/sports/baseball/roster/travis-chestnut/11817', '/sports/baseball/roster/eldridge-armstrong%20iii/12461', '/sports/baseball/roster/jason-bodin/12453', '/sports/baseball/roster/zane-badmaev/12463', '/sports/baseball/roster/brady-sullivan/12448', '/sports/baseball/roster/brett-antolick/12452', '/sports/baseball/roster/weston-moss/12450', '/sports/baseball/roster/justin-lamkin/11830', '/sports/baseball/roster/luke-jackson/11826', '/sports/baseball/roster/josh-stewart/11837']
# []
# base_url: http://www.texastech.com
# https://www.texastech.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/zach-erdman/12734', '/sports/baseball/roster/austin-green/12737', '/sports/baseball/roster/solen-munson/13111', '/sports/baseball/roster/zane-petty/12746', '/sports/baseball/roster/jacob-rogers/12748', '/sports/baseball/roster/damian-bravo/12731', '/sports/baseball/roster/jack-washburn/13116', '/sports/baseball/roster/dylan-maxcey/12744', '/sports/baseball/roster/cade-mcgee/13102', '/sports/baseball/roster/landon-stripling/13104', '/sports/baseball/roster/kevin-bazzell/12730', '/sports/baseball/roster/mac-heuer/13117', '/sports/baseball/roster/gavin-kash/12739', '/sports/baseball/roster/trendan-parish/12745', '/sports/baseball/roster/brendan-lysik/12743', '/sports/baseball/roster/kyle-robinson/12747', '/sports/baseball/roster/garet-boehm/13097', '/sports/baseball/roster/max-huffling/13115', '/sports/baseball/roster/owen-washburn/12750', '/sports/baseball/roster/derek-bridges/12732', '/sports/baseball/roster/gage-harrelson/12738', '/sports/baseball/roster/hudson-parker/13099', '/sports/baseball/roster/tj-pompey/13096', '/sports/baseball/roster/cole-kaase/13109', '/sports/baseball/roster/parker-hutyra/13105', '/sports/baseball/roster/carson-priebe/13108', '/sports/baseball/roster/ryan-free/12736', '/sports/baseball/roster/josh-sanders/12749', '/sports/baseball/roster/davis-rivers/13101', '/sports/baseball/roster/will-burns/12733', '/sports/baseball/roster/brady-trombello/13113', '/sports/baseball/roster/tracer-lopez/12742', '/sports/baseball/roster/drew-woodcox/12751', '/sports/baseball/roster/travis-sanders/13103', '/sports/baseball/roster/taber-fast/12735', '/sports/baseball/roster/joe-sockwell/13107', '/sports/baseball/roster/chandler-coe/13110', '/sports/baseball/roster/isaiah-rhodes/13106', '/sports/baseball/roster/carson-baugh/13112', '/sports/baseball/roster/hudson-luce/13114']
# []
# base_url: http://www.goutsa.com
# 404 Error
# 404 Error
# https://www.goutsa.com/sports/baseball/roster/
# ['/sports/baseball/roster/season/2024/player/cooper-hrbacek', '/sports/baseball/roster/season/2024/staff/mikey-bielamowicz', '/sports/baseball/roster/season/2024/player/hector-rodriguez', '/sports/baseball/roster/season/2024/player/drake-smith', '/sports/baseball/roster/season/2024/player/zane-spinn', '/sports/baseball/roster/season/2024/player/fischer-kingsbery', '/sports/baseball/roster/season/2024/player/diego-diaz', '/sports/baseball/roster/season/2024/player/caleb-hill', '/sports/baseball/roster/season/2024/player/tye-odom', '/sports/baseball/roster/season/2024/player/aiden-baumann', '/sports/baseball/roster/season/2024/staff/natalie-garcia', '/sports/baseball/roster/season/2024/player/lucas-moore', '/sports/baseball/roster/season/2024/staff/pat-hallmark', '/sports/baseball/roster/season/2024/player/connor-kelley', '/sports/baseball/roster/season/2024/player/dalton-porter', '/sports/baseball/roster/season/2024/player/anthony-giannette', '/sports/baseball/roster/season/2024/player/tanner-sever', '/sports/baseball/roster/season/2024/player/barrett-johnson', '/sports/baseball/roster/season/2024/player/ryan-beaird', '/sports/baseball/roster/season/2024/player/braden-davis', '/sports/baseball/roster/season/2024/player/broc-parmer', '/sports/baseball/roster/season/2024/player/lorenzo-morresi', '/sports/baseball/roster/season/2024/player/colin-carrejo', '/sports/baseball/roster/season/2024/staff/andrew-shibata', '/sports/baseball/roster/season/2024/player/zachary-longshore', '/sports/baseball/roster/season/2024/player/conor-myles', '/sports/baseball/roster/season/2024/player/mason-lytle', '/sports/baseball/roster/season/2024/player/andrew-stucky', '/sports/baseball/roster/season/2024/player/isaiah-walker', '/sports/baseball/roster/season/2024/player/ryan-jester', '/sports/baseball/roster/season/2024/player/daniel-garza', '/sports/baseball/roster/season/2024/staff/ryan-aguayo', '/sports/baseball/roster/season/2024/player/james-taussig', '/sports/baseball/roster/season/2024/player/hank-howard', '/sports/baseball/roster/season/2024/staff/andres-garza', '/sports/baseball/roster/season/2024/player/mark-henning', '/sports/baseball/roster/season/2024/player/ulises-quiroga', '/sports/baseball/roster/season/2024/player/ruger-riojas', '/sports/baseball/roster/season/2024/player/robert-orloski', '/sports/baseball/roster/season/2024/staff/zach-butler', '/sports/baseball/roster/season/2024/player/ty-tilson', '/sports/baseball/roster/season/2024/player/whitt-joyce', '/sports/baseball/roster/season/2024/staff/travion-smith', '/sports/baseball/roster/season/2024/player/ryan-ward', '/sports/baseball/roster/season/2024/player/matt-king', '/sports/baseball/roster/season/2024/player/zach-royse', '/sports/baseball/roster/season/2024/player/braylon-owens', '/sports/baseball/roster/season/2024/player/alex-olivo']
# []
# base_url: http://troytrojans.com
# https://troytrojans.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/lance-gardiner/10643', '/sports/baseball/roster/parker-sessions/10653', '/sports/baseball/roster/colton-walls/10850', '/sports/baseball/roster/cooper-smith/10836', '/sports/baseball/roster/ty-denton/10849', '/sports/baseball/roster/jay-dill/10844', '/sports/baseball/roster/will-butcher/10834', '/sports/baseball/roster/jacob-roettgen/10847', '/sports/baseball/roster/kristian-asbury/10636', '/sports/baseball/roster/sam-schmidt/10843', '/sports/baseball/roster/grayson-stewart/10655', '/sports/baseball/roster/logan-ross/10652', '/sports/baseball/roster/kyle-mock/10649', '/sports/baseball/roster/ryan-pettys/10651', '/sports/baseball/roster/aidan-gilroy/10831', '/sports/baseball/roster/blake-sutton/10838', '/sports/baseball/roster/brooks-bryan/10637', '/sports/baseball/roster/noah-manning/10647', '/sports/baseball/roster/ethan-kavanagh/10645', '/sports/baseball/roster/grady-gorgen/10644', '/sports/baseball/roster/jayden-sloan/10851', '/sports/baseball/roster/michael-osmond/10833', '/sports/baseball/roster/beau-fletcher/10639', '/sports/baseball/roster/clete-hartzog/10839', '/sports/baseball/roster/josh-dima/10837', '/sports/baseball/roster/garrett-gainous/10642', '/sports/baseball/roster/pavlos-piperakis/10852', '/sports/baseball/roster/brady-fuller/10640', '/sports/baseball/roster/tremayne-cobb%20jr/10638', '/sports/baseball/roster/mikey-bello/10842', '/sports/baseball/roster/matt-mercer/10648', '/sports/baseball/roster/kole-myers/10650', '/sports/baseball/roster/luke-lyon/10848', '/sports/baseball/roster/peyton-watts/10845', '/sports/baseball/roster/jason-hawkins/10835', '/sports/baseball/roster/isaac-silva/10832', '/sports/baseball/roster/jakob-wax/10853', '/sports/baseball/roster/trevor-bagwell/10846', '/sports/baseball/roster/zak-szabo/10656', '/sports/baseball/roster/connor-burt/10841', '/sports/baseball/roster/shane-lewis/10646', '/sports/baseball/roster/dylan-king/10840', '/sports/baseball/roster/ben-arnett/10635']
# []
# base_url: http://www.goairforcefalcons.com/
# https://www.goairforcefalcons.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/jake-greiving/18184', '/sports/baseball/roster/cooper-loveridge/18189', '/sports/baseball/roster/tripp-garrish/18182', '/sports/baseball/roster/aerik-joe/18186', '/sports/baseball/roster/bowen-brantingham/18212', '/sports/baseball/roster/landon-boyd/18179', '/sports/baseball/roster/sam-kulasingam/18188', '/sports/baseball/roster/ben-niednagel/18191', '/sports/baseball/roster/chase-spencer/18197', '/sports/baseball/roster/charlie-jones/18187', '/sports/baseball/roster/chris-stallings/18198', '/sports/baseball/roster/christian-taylor/18213', '/sports/baseball/roster/van-klein/18207', '/sports/baseball/roster/gaines-estridge/18205', '/sports/baseball/roster/jimmy-hebenstreit/18185', '/sports/baseball/roster/connor-bartz/18209', '/sports/baseball/roster/connor-christenson/18208', '/sports/baseball/roster/dylan-rogers/18195', '/sports/baseball/roster/sam-hentges/18211', '/sports/baseball/roster/joey-collier/18180', '/sports/baseball/roster/ethan-dillinger/18214', '/sports/baseball/roster/jaxson-crump/18181', '/sports/baseball/roster/jack-bello/18178', '/sports/baseball/roster/jay-thomason/18199', '/sports/baseball/roster/zach-peters/18193', '/sports/baseball/roster/patrick-davidson/18206', '/sports/baseball/roster/seungmin-shim/18196', '/sports/baseball/roster/cam-anstey/18216', '/sports/baseball/roster/davis-rhyne/18215', '/sports/baseball/roster/luke-elmore/18210', '/sports/baseball/roster/doyle-gehring/18183', '/sports/baseball/roster/t.j.-oster/18192', '/sports/baseball/roster/aaron-reyes/18194', '/sports/baseball/roster/walker-zapp/18201', '/sports/baseball/roster/charlie-russell/18203', '/sports/baseball/roster/ben-weber/18200', '/sports/baseball/roster/gio-sambito/18204', '/sports/baseball/roster/kyle-moats/18190']
# []
# base_url: https://goarmywestpoint.com/
# https://goarmywestpoint.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/zac-farrell/20968', '/sports/baseball/roster/kevin-luke/20975', '/sports/baseball/roster/coleson-titus/20984', '/sports/baseball/roster/andrew-berg/20962', '/sports/baseball/roster/joel-rubin/20980', '/sports/baseball/roster/robbie-penswick/20990', '/sports/baseball/roster/derek-berg/20963', '/sports/baseball/roster/steven-graver/20971', '/sports/baseball/roster/dom-trippi/20985', '/sports/baseball/roster/william-parker/20977', '/sports/baseball/roster/thomas-schreck/20983', '/sports/baseball/roster/trey-ates/20989', '/sports/baseball/roster/parker-massey/21597', '/sports/baseball/roster/jack-morken/20976', '/sports/baseball/roster/cj-deblasi/20995', '/sports/baseball/roster/addison-ainsworth/20960', '/sports/baseball/roster/jakob-vanderhave/20996', '/sports/baseball/roster/andy-neal/20997', '/sports/baseball/roster/billy-steele/21596', '/sports/baseball/roster/joe-valchar/20986', '/sports/baseball/roster/jack-quinlan/20978', '/sports/baseball/roster/sam-ruta/20982', '/sports/baseball/roster/paul-andrzejewski/21051', '/sports/baseball/roster/bryce-brownlee/20964', '/sports/baseball/roster/ethan-ellis/20967', '/sports/baseball/roster/max-mcglone/20988', '/sports/baseball/roster/jared-cohen/20965', '/sports/baseball/roster/tanner-gresham/20972', '/sports/baseball/roster/justin-lehman/20974', '/sports/baseball/roster/mike-ruggieri/20981', '/sports/baseball/roster/braden-golinski/20970', '/sports/baseball/roster/owen-wade/20991', '/sports/baseball/roster/matthew-ronnebaum/20979', '/sports/baseball/roster/chris-barr/20961', '/sports/baseball/roster/trevor-finan/20969', '/sports/baseball/roster/luke-marino/20994', '/sports/baseball/roster/carter-hewitt/20973', '/sports/baseball/roster/sean-dennehy/20966', '/sports/baseball/roster/mark-abell/20992', '/sports/baseball/roster/john-oxios/20987']
# []
# base_url: http://www.valpoathletics.com
# Redirect occurred for: https://www.valpoathletics.com/sports/baseball/roster/2024 Didnt match: https://www.valpoathletics.com/baseball/
# https://www.valpoathletics.com/baseball/roster/2024
# ['/baseball/roster/2023-24/13651/ryan-kruse/', '/wbasketball/roster/', '/baseball/roster/2024/?view=list', '/baseball/roster/2009-10/', '/baseball/roster/2014-15/', '/baseball/roster/2023-24/13634/kade-reinertson/', '/baseball/roster/2023-24/13649/connor-giusti/', '/mswim/roster/', '/baseball/roster/2008-09/', '/danceteam/roster/', '/baseball/roster/2023-24/13625/alex-thurston/', '/baseball/roster/2023-24/13645/jack-thompson/', '/football/roster/', '/baseball/roster/2023-24/13648/carson-husmann/', '/baseball/roster/2010-11/', '/baseball/roster/2023-24/', '/wcc/roster/', '/baseball/roster/2006-07/', '/baseball/roster/2023-24/13654/bryce-konitzer/', '/baseball/roster/2023-24/13662/brady-glisic/', '/mtrack/roster/', '/baseball/roster/2023-24/13639/kyle-schmack/', '/baseball/roster/2023-24/13633/jonathan-hyman/', '/baseball/roster/2023-24/13642/grant-jablonski/', '/baseball/roster/2023-24/13626/josh-spencer/', '/baseball/roster/2019-20/', '/wtrack/roster/', '/baseball/roster/2023-24/13624/spencer-warfield/', '/baseball/roster/2023-24/13650/bennett-musser/', '/baseball/roster/2023-24/13644/griffin-mccluskey/', '/baseball/roster/2023-24/13635/brady-nowicki/', '/baseball/roster/2023-24/13641/brady-renfro/', '/baseball/roster/2023-24/13628/connor-lockwood/', '/baseball/roster/2023-24/13661/jeff-mayes/', '/baseball/roster/2023-24/13638/adam-guazzo/', '/mbasketball/roster/', '/wtennis/roster/', '/baseball/roster/2023-24/13656/chase-maifield/', '/softball/roster/', '/wgolf/roster/', '/baseball/roster/2017-18/', '/baseball/roster/2023-24/13643/trent-turzenski/', '/baseball/roster/2023-24/13646/aidan-thaxton/', '/baseball/roster/2011-12/', '/baseball/roster/2002-03/', '/baseball/roster/2023-24/13653/joe-seiber/', '/baseball/roster/2023-24/13629/thomas-cooper/', '/baseball/roster/2004-05/', '/baseball/roster/2023-24/13659/brian-schmack/', '/wsoccer/roster/', '/baseball/roster/2023-24/13637/ryan-maka/', '/baseball/roster/2023-24/13658/lucas-foley/', '/baseball/roster/2013-14/', '/baseball/roster/default/', '/wbowling/roster/', '/baseball/roster/2023-24/13657/jake-jakubowski/', '/baseball/roster/2023-24/13655/liam-patton/', '/baseball/roster/2023-24/13632/alex-ryan/', '/baseball/roster/2023-24/13627/christian-hack/', '/baseball/roster/2023-24/13623/will-radich/', '/baseball/roster/2022-23/', '/cheer/roster/', '/baseball/roster/', '/baseball/roster/2023-24/13630/kaleb-hannahs/', '/wswim/roster/', '/baseball/roster/2023-24/13640/patrick-ilitch/', '/baseball/roster/2016-17/', '/baseball/roster/2020-21/', '/baseball/roster/2015-16/', '/baseball/roster/2012-13/', '/baseball/roster/2023-24/13790/adam-brian/', '/mcc/roster/', '/baseball/roster/2023-24/13631/josh-cottrill/', '/baseball/roster/2018-19/', '/baseball/roster/2023-24/13647/kevin-denty/', '/baseball/roster/2023-24/13660/kory-winter/', '/volleyball/roster/', '/baseball/roster/2007-08/', '/baseball/roster/2023-24/13636/kaleb-krier/', '/baseball/roster/2021-22/', '/baseball/roster/2005-06/', '/baseball/roster/2023-24/13652/spencer-boynton/', '/mgolf/roster/', '/baseball/roster/2003-04/']
# []
# base_url: http://vucommodores.com
# Redirect occurred for: https://vucommodores.com/sports/baseball/roster/2024 Didnt match: https://vucommodores.com/
# Redirect occurred for: https://vucommodores.com/baseball/roster/2024 Didnt match: https://vucommodores.com/
# https://vucommodores.com/sports/baseball/roster/
# ['/sports/wten/roster/', '/sports/baseball/roster/season/2023-24/player/rj-austin/', '/sports/baseball/roster/season/2023-24/player/jack-bulger/', '/sports/baseball/roster/season/2023-24/player/davis-diaz/', '/sports/baseball/roster/season/2023-24/player/sam-hliboki/', '/sports/baseball/roster/season/2023-24/player/sawyer-hawks/', '/sports/baseball/roster/season/2023-24/player/camden-kozeal/', '/sports/baseball/roster/season/2023-24/player/ethan-robinson/', '/sports/baseball/roster/season/2023-24/player/david-horn/', '/sports/baseball/roster/season/2023-24/player/colton-regen/', '/sports/baseball/roster/season/2023-24/player/duke-ekstrom/', '/sports/wbowl/roster/', '/sports/baseball/roster/season/2023-24/player/logan-poteet/', '/sports/baseball/roster/season/2023-24/player/deegan-cordova/', '/sports/baseball/roster/season/2023-24/player/jakob-schulz/', '/sports/baseball/roster/season/2023-24/player/devin-futrell/', '/sports/baseball/roster/season/2023-24/player/raymond-velazquez/', '/sports/baseball/roster/season/2023-24/player/colin-barczi/', '/sports/mbball/roster/', '/sports/baseball/roster/season/2023-24/player/alan-espinal/', '/sports/wswim/roster/', '/sports/baseball/roster/season/2023-24/player/brennan-seiber/', '/sports/baseball/roster/season/2023-24/player/ethan-mcelvain/', '/sports/baseball/roster/season/2023-24/player/matt-wolfe/', '/sports/baseball/roster/season/2023-24/player/jayden-davis/', '/sports/baseball/roster/season/2023-24/player/rj-hamilton/', '/sports/baseball/roster/season/2023-24/player/troy-laneve/', '/sports/baseball/roster/season/2023-24/player/luke-guth/', '/sports/baseball/roster/season/2023-24/player/levi-huesman/', '/sports/baseball/roster/season/2023-24/player/nik-copenhaver/', '/sports/baseball/roster/season/2023-24/player/matthew-polk/', '/sports/baseball/roster/season/2023-24/player/bryce-cunningham/', '/sports/baseball/roster/season/2023-24/player/jacob-humphrey/', '/sports/wbball/roster/', '/sports/baseball/roster/season/2023-24/player/calvin-hewett/', '/sports/wgolf/roster/', '/sports/baseball/roster/season/2023-24/player/miller-green/', '/sports/baseball/roster/season/2023-24/player/greysen-carter/', '/sports/baseball/roster/season/2023-24/player/kaito-muto/', '/sports/wsoc/roster/', '/sports/baseball/roster/season/2023-24/player/jd-rogers/', '/sports/football/roster/', '/sports/baseball/roster/season/2023-24/player/andrew-dutkanych-iv/', '/sports/baseball/roster/season/2023-24/player/jonathan-vastine/', '/sports/baseball/roster/season/2023-24/player/chris-maldonado/', '/sports/baseball/roster/season/2023-24/player/devan-kodali/', '/sports/wlax/roster/', '/sports/baseball/roster/season/2023-24/player/jd-thompson/', '/sports/baseball/roster/season/2023-24/player/braden-holcomb/', '/sports/mcross/roster/', '/sports/baseball/roster/season/2023-24/player/carter-holton/', '/sports/baseball/roster/season/2023-24/player/alex-kranzler/', '/sports/mten/roster/', '/sports/mgolf/roster/', '/sports/wtrack/roster/', '/sports/baseball/roster/season/2023-24/player/cooper-holbrook/', '/sports/baseball/roster/season/2023-24/player/nate-teague/', '/sports/baseball/roster/season/2023-24/player/matt-ossenfort/', '/sports/wcross/roster/', '/sports/baseball/roster/', '/sports/baseball/roster/season/2023-24/player/ryan-ginther/']
# []
# base_url: http://www.hokiesports.com
# https://www.hokiesports.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/2024?print=true']
# []
# base_url: http://www.virginiasports.com
# Redirect occurred for: https://www.virginiasports.com/sports/baseball/roster/2024 Didnt match: https://virginiasports.com/news/2013/09/30/rosters-announced-for-orange-amp-blue-world-series/
# Redirect occurred for: https://www.virginiasports.com/baseball/roster/2024 Didnt match: https://virginiasports.com/news/2013/09/30/rosters-announced-for-orange-amp-blue-world-series/
# https://www.virginiasports.com/sports/baseball/roster/
# ['/sports/msquash/roster/', '/sports/wten/roster/', '/sports/baseball/roster/#staff', '/sports/baseball/roster/season/2023-24/player/jack-oconnor/', '/sports/baseball/roster/season/2023-24/player/anthony-stephan/', '/sports/baseball/roster/season/2023-24/player/angelo-tonas/', '/sports/baseball/roster/season/2023-24/player/harrison-didawick/', '/sports/baseball/roster/season/2023-24/coach/john-hendry/', '/sports/baseball/roster/season/2023-24/coach/brian-mcguire/', '/sports/baseball/roster/season/2023-24/player/tristan-head/', '/sports/baseball/roster/season/2023-24/player/matthew-buchanan/', '/sports/baseball/roster/season/2023-24/coach/andrew-behnam/', '/sports/baseball/roster/season/2023-24/player/cullen-mckay/', '/sports/baseball/roster/season/2023-24/player/henry-godbout/', '/sports/baseball/roster/season/2023-24/player/matt-augustin/', '/sports/baseball/roster/season/2023-24/player/bobby-whalen/', '/sports/baseball/roster/season/2023-24/player/antonio-perrotta/', '/sports/baseball/roster/season/2023-24/player/ryan-osinski/', '/sports/baseball/roster/season/2023-24/player/eric-becker/', '/sports/xc/roster/', '/sports/baseball/roster/season/2023-24/player/luke-hanson/', '/sports/baseball/roster/season/2023-24/player/patric-menk/', '/sports/mbball/roster/', '/sports/baseball/roster/season/2023-24/player/bryson-moore/', '/sports/baseball/roster/season/2023-24/coach/kevin-mcmullan/', '/sports/baseball/roster/season/2023-24/coach/drew-dickinson/', '/sports/baseball/roster/season/2023-24/player/blake-barker/', '/sports/mlax/roster/', '/sports/baseball/roster/season/2023-24/player/chase-hungate/', '/sports/xctrack/roster/', '/sports/fhockey/roster/', '/sports/baseball/roster/season/2023-24/player/aidan-teel/', '/sports/baseball/roster/season/2023-24/player/kevin-jaxel/', '/sports/baseball/roster/season/2023-24/coach/kraigen-rasalla/', '/sports/baseball/roster/season/2023-24/player/ethan-anderson/', '/sports/baseball/roster/season/2023-24/player/dean-kampschror/', '/sports/baseball/roster/season/2023-24/coach/brian-oconnor/', '/sports/wsquash/roster/', '/sports/baseball/roster/season/2023-24/coach/matt-kirby/', '/sports/baseball/roster/season/2023-24/player/owen-coady/', '/sports/baseball/roster/season/2023-24/player/bradley-hodges/', '/sports/wbball/roster/', '/sports/baseball/roster/season/2023-24/player/evan-blanco/', '/sports/wgolf/roster/', '/sports/baseball/roster/season/2023-24/player/luke-schauer/', '/sports/softball/roster/', '/sports/wsoc/roster/', '/sports/football/roster/', '/sports/baseball/roster/season/2023-24/player/jacob-ference/', '/sports/baseball/roster/season/2023-24/player/nate-bassett/', '/sports/baseball/roster/season/2023-24/player/casey-saucke/', '/sports/baseball/roster/season/2023-24/player/joe-savino/', '/sports/baseball/roster/season/2023-24/player/walker-buchanan/', '/sports/wlax/roster/', '/sports/baseball/roster/season/2023-24/player/mark-gialluisi/', '/sports/baseball/roster/season/2023-24/player/henry-ford/', '/sports/baseball/roster/season/2023-24/player/tommy-roldan/', '/sports/wrow/roster/', '/sports/mten/roster/', '/sports/mgolf/roster/', '/sports/wrestling/roster/', '/sports/baseball/roster/season/2023-24/player/griff-oferrall/', '/sports/baseball/roster/season/2023-24/player/freddy-beruvides-jr/', '/sports/swimming/roster/', '/sports/wvball/roster/', '/sports/msoc/roster/', '/sports/baseball/roster/season/2023-24/coach/justin-armistead/', '/sports/baseball/roster/season/2023-24/player/charlie-oschell/', '/sports/baseball/roster/season/2023-24/player/jay-woolfolk-baseball/', '/sports/baseball/roster/']
# []
# base_url: http://www.godeacs.com
# https://www.godeacs.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/austin-hawke/8092', '/sports/baseball/roster/nick-kurtz/8074', '/sports/baseball/roster/mitchell-salvino/8096', '/sports/baseball/roster/jake-reinisch/8078', '/sports/baseball/roster/seaver-king/8090', '/sports/baseball/roster/chase-burns/8104', '/sports/baseball/roster/cole-roland/8079', '/sports/baseball/roster/antonio-morales/8100', '/sports/baseball/roster/haiden-leffew/8098', '/sports/baseball/roster/cameron-gill/8103', '/sports/baseball/roster/jacob-burley/8106', '/sports/baseball/roster/jeter-polledo/8097', '/sports/baseball/roster/joe-ariola/8067', '/sports/baseball/roster/ben-shenosky/8080', '/sports/baseball/roster/dylan-zucker/8084', '/sports/baseball/roster/pirmin-brechbuhl/8068', '/sports/baseball/roster/david-falco%20jr./8095', '/sports/baseball/roster/javar-williams/8094', '/sports/baseball/roster/andrew-koshy/8093', '/sports/baseball/roster/hudson-lee/8075', '/sports/baseball/roster/will-gervase/8086', '/sports/baseball/roster/chris-katz/8073', '/sports/baseball/roster/levi-strahm/8105', '/sports/baseball/roster/josh-gunther/8101', '/sports/baseball/roster/liam-willson/8091', '/sports/baseball/roster/marek-houston/8070', '/sports/baseball/roster/luke-schmolke/8119', '/sports/baseball/roster/michael-massey/8076', '/sports/baseball/roster/tate-ballestero/8085', '/sports/baseball/roster/ryan-preisano/8107', '/sports/baseball/roster/blake-morningstar/8089', '/sports/baseball/roster/adam-tellier/8087', '/sports/baseball/roster/crawford-wade/8081', '/sports/baseball/roster/cam-nelson/8099', '/sports/baseball/roster/jack-winnay/8083', '/sports/baseball/roster/brody-shawn/8088', '/sports/baseball/roster/josh-hartle/8069', '/sports/baseball/roster/zach-johnston/8071', '/sports/baseball/roster/william-ray/8077', '/sports/baseball/roster/chase-walter/8082']
# []
# base_url: http://www.wkusports.com
# https://www.wkusports.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/austin-haller/5147', '/sports/baseball/roster/jaylin-rae/5149', '/sports/baseball/roster/ethan-lizama/5158', '/sports/baseball/roster/jace-kirby/5157', '/sports/baseball/roster/tyler-rardin/5168', '/sports/baseball/roster/zac-carroll/5152', '/sports/baseball/roster/caleb-marmo/5151', '/sports/baseball/roster/cole-heath/5141', '/sports/baseball/roster/anthony-westbrook/5171', '/sports/baseball/roster/lane-diuguid/5139', '/sports/baseball/roster/zach-due&ntilde;as/5170', '/sports/baseball/roster/kyle-hayes/5177', '/sports/baseball/roster/dawson-hall/5140', '/sports/baseball/roster/cristian-garcia/5155', '/sports/baseball/roster/dylan-mannino/5180', '/sports/baseball/roster/lucas-litteral/5153', '/sports/baseball/roster/drew-whalen/5179', '/sports/baseball/roster/coby-moe/5181', '/sports/baseball/roster/brady-browning/5154', '/sports/baseball/roster/blake-cavill/5172', '/sports/baseball/roster/luke-leverton/5174', '/sports/baseball/roster/elliott-rossell/5145', '/sports/baseball/roster/hunter-small/5162', '/sports/baseball/roster/bryce-nevils/5161', '/sports/baseball/roster/eli-burwash/5148', '/sports/baseball/roster/cal-higgins/5142', '/sports/baseball/roster/grant-burleson/5164', '/sports/baseball/roster/cory-bosecker/5156', '/sports/baseball/roster/bryer-arview/5160', '/sports/baseball/roster/mason-burns/5138', '/sports/baseball/roster/carlos-vasquez/5163', '/sports/baseball/roster/ryan-fowler/5167', '/sports/baseball/roster/jack-bennett/5137', "/sports/baseball/roster/dylan-o'connell/5166", '/sports/baseball/roster/jacob-bimbi/5159', '/sports/baseball/roster/patrick-morris/5175', '/sports/baseball/roster/camden-ross/5144', '/sports/baseball/roster/joey-baran/5150', '/sports/baseball/roster/zayd-brannigan/5146', '/sports/baseball/roster/zach-lyles/5165']
# []
# base_url: http://www.goxavier.com
# https://www.goxavier.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/nolan-hughes/11750', '/sports/baseball/roster/connor-misch/11737', '/sports/baseball/roster/donavan-canterberry/11724', '/sports/baseball/roster/grant-stephenson/11741', '/sports/baseball/roster/braxton-brinegar/11746', '/sports/baseball/roster/alex-vera/11760', '/sports/baseball/roster/jack-niedringhaus/11738', '/sports/baseball/roster/isaac-wachsmann/11742', '/sports/baseball/roster/joe-karpierz/11734', '/sports/baseball/roster/nathan-stahl/11740', '/sports/baseball/roster/terry-murray/11752', '/sports/baseball/roster/jonathan-kelly/11735', '/sports/baseball/roster/jake-hooker/11749', '/sports/baseball/roster/matthew-aukerman/11744', '/sports/baseball/roster/nick-boyle/11723', '/sports/baseball/roster/jimmy-starnes/11759', '/sports/baseball/roster/aedan-anderson/11721', '/sports/baseball/roster/tyler-stack/11758', '/sports/baseball/roster/luke-hoskins/11732', '/sports/baseball/roster/eli-bridenthal/11745', '/sports/baseball/roster/matthew-deprey/11728', '/sports/baseball/roster/tyler-sausville/11755', '/sports/baseball/roster/hayden-christiansen/11725', '/sports/baseball/roster/garrett-schultz/11739', '/sports/baseball/roster/connor-bailey/11722', '/sports/baseball/roster/carter-hendrickson/11731', '/sports/baseball/roster/griffin-seibel/11757', '/sports/baseball/roster/luke-hammond/11730', '/sports/baseball/roster/jake-lambdin/11751', '/sports/baseball/roster/drew-zemaitis/11762', '/sports/baseball/roster/jared-gadd/11729', '/sports/baseball/roster/caleb-anderson/11743', '/sports/baseball/roster/tyler-demartino/11727', '/sports/baseball/roster/aidan-zakarewicz/11761', '/sports/baseball/roster/ashton-chronister/11747', '/sports/baseball/roster/ryan-hussey/11796', '/sports/baseball/roster/aiden-cook/11748', '/sports/baseball/roster/matt-mccormick/11736', '/sports/baseball/roster/ryan-piech/11753', '/sports/baseball/roster/jared-cushing/11726', '/sports/baseball/roster/eric-podgorny/11754', '/sports/baseball/roster/logan-schmidt/11756']
# []
# base_url: http://www.rolltide.com
# https://www.rolltide.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/will-plattner/10441', '/sports/baseball/roster/aidan-moza/10415', '/sports/baseball/roster/evan-haeger/10431', '/sports/baseball/roster/kameron-guangorena/10430', '/sports/baseball/roster/connor-ball/10402', '/sports/baseball/roster/jansen-kenty/10433', '/sports/baseball/roster/alton-davis%20ii/10404', '/sports/baseball/roster/pierce-george/10428', '/sports/baseball/roster/sammy-leis/10412', '/sports/baseball/roster/william-hamiter/10408', '/sports/baseball/roster/greg-farone/10427', '/sports/baseball/roster/zane-probst/10418', '/sports/baseball/roster/austin-morris/10414', '/sports/baseball/roster/joey-rubin/10444', '/sports/baseball/roster/evan-sleight/10445', '/sports/baseball/roster/ariston-veasey/10449', '/sports/baseball/roster/sam-mitchell/10437', '/sports/baseball/roster/parker-picot/10440', '/sports/baseball/roster/bobby-alcock/10423', '/sports/baseball/roster/bryce-eblin/10405', '/sports/baseball/roster/mac-guscette/10407', '/sports/baseball/roster/ian-petrutz/10439', '/sports/baseball/roster/braylon-myers/10416', '/sports/baseball/roster/hagan-banks/10403', '/sports/baseball/roster/jonathan-stevens/10447', '/sports/baseball/roster/luke-williams/10421', '/sports/baseball/roster/tyler-fay/10406', '/sports/baseball/roster/ben-hess/10410', '/sports/baseball/roster/will-portera/10417', '/sports/baseball/roster/justin-lebron/10434', '/sports/baseball/roster/zane-adams/10422', '/sports/baseball/roster/2024', '/sports/baseball/roster/kade-snell/10446', '/sports/baseball/roster/max-grant/10429', '/sports/baseball/roster/mason-swinney/10420', '/sports/baseball/roster/gage-miller/10436', '/sports/baseball/roster/will-hodo/10411', '/sports/baseball/roster/riley-quick/10419', '/sports/baseball/roster/matthew-heiberger/10432', '/sports/baseball/roster/beau-brailey/10425', '/sports/baseball/roster/coulson-buchanan/10426', '/sports/baseball/roster/luke-vaughn/10448', '/sports/baseball/roster/jackson-baker/10424', '/sports/baseball/roster/camden-hayslip/10409', '/sports/baseball/roster/tate-robertson/10443', '/sports/baseball/roster/tj-mccants/10435', '/sports/baseball/roster/coleman-mizell/10438']
# []
# base_url: http://www.uabsports.com
# https://www.uabsports.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/nick-hollifield/10322', '/sports/baseball/roster/reed-latimer/10462', '/sports/baseball/roster/tyler-harrington/10455', '/sports/baseball/roster/leo-harris/10704', '/sports/baseball/roster/logan-braunschweig/10313', '/sports/baseball/roster/christian-stratis/10466', '/sports/baseball/roster/tyler-haines/10321', '/sports/baseball/roster/jax-yoxtheimer/10468', '/sports/baseball/roster/thomas-ballard/10311', '/sports/baseball/roster/ty-hutto/10461', '/sports/baseball/roster/alan-choo/10453', '/sports/baseball/roster/caden-long/10706', '/sports/baseball/roster/andrew-hunt/10460', '/sports/baseball/roster/matthew-bullard/10451', '/sports/baseball/roster/brooks-house/10459', '/sports/baseball/roster/isaac-warrick/10333', '/sports/baseball/roster/david-harris/10456', '/sports/baseball/roster/brock-hill/10458', '/sports/baseball/roster/christian-clack/10317', '/sports/baseball/roster/austin-young/10338', '/sports/baseball/roster/isaiah-mack/10327', '/sports/baseball/roster/alex-cheeseman/10452', '/sports/baseball/roster/colin-patterson/10464', '/sports/baseball/roster/mayes-white/10335', '/sports/baseball/roster/carson-knight/10325', '/sports/baseball/roster/brayton-brown/10314', '/sports/baseball/roster/jake-smallwood/10465', '/sports/baseball/roster/blayze-berry/10312', '/sports/baseball/roster/darryl-buggs/10315', '/sports/baseball/roster/peyton-puckett/10329', '/sports/baseball/roster/braxton-shelton/10330', '/sports/baseball/roster/colin-daniel/10318', '/sports/baseball/roster/john%20luke-marlin/10328', '/sports/baseball/roster/nick-martinez/10463', '/sports/baseball/roster/joe-watkins/10467', '/sports/baseball/roster/tyler-waugh/10334', '/sports/baseball/roster/ben-abernathy/10310', '/sports/baseball/roster/chase-ingram/10324', '/sports/baseball/roster/braxton-brooks/10454', '/sports/baseball/roster/gavin-lewis%20jr./10326']
# []
# base_url: http://arkansasrazorbacks.com/
# 404 Error
# 404 Error
# 404 Error
# Redirect occurred for: https://arkansasrazorbacks.com/baseball/roster/ Didnt match: https://arkansasrazorbacks.com/sport/m-basebl/roster/
# https://arkansasrazorbacks.com/sport/m-basebl/roster/
# ['/sport/m-golf/roster/#coaches', '/sport/w-volley/roster/', '/sport/w-softbl/roster/#coaches', '/roster/will-mcentire/', '/roster/peyton-holt/', '/roster/will-edmunson/', '/sport/w-tennis/roster/#coaches', '/sport/w-gym/roster/', '/roster/hunter-grimes/', '/roster/kade-smith/', '/roster/jaewoo-cho/', '/sport/m-footbl/roster/#coaches', '/sport/w-soccer/roster/', '/roster/christian-foutch/', '/roster/jayson-jones/', '/sport/w-tennis/roster/', '/roster/ty-waid/', '/roster/stone-hewlett/', '/sport/w-track/roster/#coaches', '/roster/parker-rowland/', '/roster/josh-hyneman/', '/roster/peyton-stovall/', '/sport/m-track/roster/', '/sport/w-gym/roster/#coaches', '/roster/hudson-white/', '/sport/m-track/roster/#coaches', '/sport/m-golf/roster/', '/roster/tucker-holland/', '/roster/hagen-smith/', '/roster/dylan-carter/', '/roster/hunter-dietz/', '/sport/w-baskbl/roster/', '/roster/adam-hachman/', '/sport/w-golf/roster/', '/roster/tate-mcguire/', '/roster/kendall-diggs/', '/sport/m-footbl/roster/', '/roster/cooper-dossett/', '/roster/brady-tygart/', '/sport/m-baskbl/roster/#coaches', '/roster/nolan-souza/', '/roster/hudson-polk/', '/sport/w-volley/roster/#coaches', '/sport/w-swim/roster/#coaches', '/sport/w-track/roster/', '/roster/jack-wagner/', '/sport/w-xc/roster/#coaches', '/roster/reese-robinett/', '/sport/m-basebl/roster/', '/roster/ty-wilmsmeyer/', '/sport/m-tennis/roster/', '/sport/m-baskbl/roster/', '/sport/w-golf/roster/#coaches', '/sport/m-basebl/roster/#coaches', '/sport/w-xc/roster/', '/roster/ryder-helfrick/', '/sport/m-xc/roster/', '/roster/koty-frank/', '/roster/ben-mclaughlin/', '/roster/gage-wood/', '/sport/m-tennis/roster/#coaches', '/sport/w-soccer/roster/#coaches', '/roster/gabe-gaeckle/', '/sport/w-swim/roster/', '/roster/wehiwa-aloy/', '/roster/jared-sprague-lott/', '/roster/ross-lovich/', '/roster/jack-smith/', '/roster/colin-fisher/', '/roster/mason-molina/', '/roster/diego-ramos/', '/roster/parker-coil/', '/sport/w-baskbl/roster/#coaches', '/roster/jake-faherty/', '/sport/w-softbl/roster/', '/sport/m-xc/roster/#coaches', '/roster/ben-bybee/']
# []
# base_url: http://www.baylorbears.com
# https://www.baylorbears.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/2024?print=true']
# []
# base_url: http://www.bcuathetics.com
# https://www.bcuathetics.com/sports/baseball/roster/2024
# []
# []
# base_url: http://www.bgsufalcons.com
# https://www.bgsufalcons.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/david-silva/18498', '/sports/baseball/roster/caden-bates/18496', '/sports/baseball/roster/landon-roque/18606', '/sports/baseball/roster/sam-seidel/18492', '/sports/baseball/roster/logan-bell/18475', '/sports/baseball/roster/levi-gazarek/18478', '/sports/baseball/roster/dj-newman/18487', '/sports/baseball/roster/carson-lumley/18484', '/sports/baseball/roster/astin-morman/18832', '/sports/baseball/roster/jacob-turner/18493', '/sports/baseball/roster/tyler-ross/18490', '/sports/baseball/roster/brock-amelung/18505', '/sports/baseball/roster/caden-parker/18506', '/sports/baseball/roster/leighton-banjoff/18474', '/sports/baseball/roster/owen-poole/18502', '/sports/baseball/roster/isaiah-seidel/18491', '/sports/baseball/roster/connar-penrod/18488', '/sports/baseball/roster/tj-takats/18499', '/sports/baseball/roster/rigo-ramos/18489', '/sports/baseball/roster/titus-lotz/18503', '/sports/baseball/roster/cooper-mckenzie/18485', '/sports/baseball/roster/calvin-mitchell/18504', '/sports/baseball/roster/landon-willeman/18494', '/sports/baseball/roster/perry-miller/18486', '/sports/baseball/roster/nic-good/18479', '/sports/baseball/roster/garrett-wright/18497', '/sports/baseball/roster/alex-laird/18501', '/sports/baseball/roster/zack-horky/18481', '/sports/baseball/roster/nate-kress/18500', '/sports/baseball/roster/nathan-archer/18472', '/sports/baseball/roster/jack-krause/18482', '/sports/baseball/roster/luke-krouse/18483', '/sports/baseball/roster/brady-birchmeier/18476', '/sports/baseball/roster/kade-arn/18473', '/sports/baseball/roster/gavin-ganun/18477', '/sports/baseball/roster/peyton-wilson/18495']
# []
# base_url: http://www.bradleybraves.com
# https://www.bradleybraves.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/2024?print=true']
# []
# base_url: http://byucougars.com
# 404 Error
# 404 Error
# https://byucougars.com/sports/baseball/roster/
# ['/sports/baseball/roster/season/2024/player/jackson-hollingshaus', '/sports/baseball/roster/season/2024/player/luke-anderson', '/sports/baseball/roster/season/2024/player/crew-mcchesney', '/sports/baseball/roster/season/2024/player/gavin-taylor', '/sports/baseball/roster/season/2024/player/parker-goff', '/sports/baseball/roster/season/2024/player/greyson-shafer', '/sports/baseball/roster/season/2024/staff/tuckett-slade', '/sports/baseball/roster/season/2024/player/cayson-bell', '/sports/baseball/roster/season/2024/player/max-stanley', '/sports/baseball/roster/season/2024/player/boston-mabeus', '/sports/baseball/roster/season/2024/player/maddax-peck', '/sports/baseball/roster/season/2024/player/jake-porter', '/sports/baseball/roster/season/2024/player/luke-sterner', '/sports/baseball/roster/season/2024/player/brock-watkins', '/sports/baseball/roster/season/2024/player/bitner-workman', '/sports/baseball/roster/season/2024/player/justis-reiser', '/sports/baseball/roster/season/2024/player/ryker-schow', '/sports/baseball/roster/#', '/sports/baseball/roster/season/2024/player/ben-hansen', '/sports/baseball/roster/season/2024/player/stone-cushing', '/sports/baseball/roster/season/2024/player/mason-olson', '/sports/baseball/roster/season/2024/player/collin-reuter', '/sports/baseball/roster/season/2024/player/bryant-ball', '/sports/baseball/roster/season/2024/player/matt-fox', '/sports/baseball/roster/season/2024/player/bryker-hurdsman', '/sports/baseball/roster/season/2024/staff/abe-alvarez', '/sports/baseball/roster/season/2024/player/austin-laycock', '/sports/baseball/roster/season/2024/staff/trent-pratt', '/sports/baseball/roster/season/2024/player/seth-rajacich', '/sports/baseball/roster/season/2024/player/keoni-painter', '/sports/baseball/roster/season/2024/player/hayden-coon', '/sports/baseball/roster/season/2024/player/cooper-vest', '/sports/baseball/roster/season/2024/player/candon-dahle', '/sports/baseball/roster/season/2024/player/carter-foss', '/sports/baseball/roster/season/2024/player/tate-gambill', '/sports/baseball/roster/season/2024/player/crew-robinson', '/sports/baseball/roster/season/2024/player/bryce-robison', '/sports/baseball/roster/season/2024/player/payton-gubler', '/sports/baseball/roster/season/2024/player/braeden-mondeau', '/sports/baseball/roster/season/2024/player/easton-jones', '/sports/baseball/roster/season/2024/player/kuhio-aloy', '/sports/baseball/roster/season/2024/player/brett-hansen', '/sports/baseball/roster/season/2024/staff/blake-hofheins', '/sports/baseball/roster/season/2024/staff/tyler-coolbaugh', '/sports/baseball/roster/season/2024/player/chipper-beck', '/sports/baseball/roster/season/2024/staff/adam-law', '/sports/baseball/roster/season/2024/player/walker-sanders', '/sports/baseball/roster/season/2024/player/cutter-clawson']
# []
# base_url: http://www.brownbears.com
# https://www.brownbears.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/miles-newsome/18187', '/sports/baseball/roster/carter-rasmussen/18181', '/sports/baseball/roster/charles-crawford/18167', '/sports/baseball/roster/conor-cooke/18166', '/sports/baseball/roster/andrew-hanlon/18190', '/sports/baseball/roster/paxton-meyers/18176', '/sports/baseball/roster/peter-dubie/18169', '/sports/baseball/roster/mark-henshon/18172', '/sports/baseball/roster/reece-rappoli/18180', '/sports/baseball/roster/brady-dever/18188', '/sports/baseball/roster/christian-keel/18174', '/sports/baseball/roster/nathan-brasher/18165', '/sports/baseball/roster/zack-siegal/18185', '/sports/baseball/roster/logan-meusy/18175', '/sports/baseball/roster/jared-johnson/18173', '/sports/baseball/roster/santhosh-gottam/18170', '/sports/baseball/roster/olivia-pichardo/18178', '/sports/baseball/roster/jack-seppings/18184', '/sports/baseball/roster/mika-petersen/18177', '/sports/baseball/roster/quinn-rooks/18183', '/sports/baseball/roster/gunner-boree/18164', '/sports/baseball/roster/ty-harris/18171', '/sports/baseball/roster/dylan-reid/18182', '/sports/baseball/roster/jacob-young/18186', '/sports/baseball/roster/stiles-begnaud/18163', '/sports/baseball/roster/brendan-chanley/18192', '/sports/baseball/roster/dj-dillehay/18168', '/sports/baseball/roster/brenden-kline/18194', '/sports/baseball/roster/brandon-chang/18189', '/sports/baseball/roster/ryan-oshinskie/18191']
# []
# base_url: http://www.bryantbulldogs.com
# 404 Error
# 404 Error
# 404 Error
# 404 Error
# 404 Error
# 404 Error
# skipped roster b/c roster page had no soup
# base_url: http://bucknellbison.com
# https://bucknellbison.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/graeme-carroll/9668', '/sports/baseball/roster/matt-alexander/9667', '/sports/baseball/roster/brady-karp/9675', '/sports/baseball/roster/sean-keys/9677', '/sports/baseball/roster/jake-schultz/9698', '/sports/baseball/roster/hadley-maxwell/9679', '/sports/baseball/roster/chris-morabito/9694', '/sports/baseball/roster/jonathan-adelmann/9697', '/sports/baseball/roster/kobe-julks/9701', '/sports/baseball/roster/mikey-myro/9681', '/sports/baseball/roster/ben-magovern/9678', "/sports/baseball/roster/tyler-o'neill/9682", '/sports/baseball/roster/ryan-delaney/9670', '/sports/baseball/roster/nikhil-patel/9683', '/sports/baseball/roster/connor-vucovich/9690', '/sports/baseball/roster/billy-kender/9676', '/sports/baseball/roster/billy-fluharty/9695', '/sports/baseball/roster/tyler-dunn/9671', '/sports/baseball/roster/dante-pavone/9696', "/sports/baseball/roster/jack-o'malley/9700", '/sports/baseball/roster/nick-mulvey/9680', '/sports/baseball/roster/jacob-corson/9669', '/sports/baseball/roster/michael-trommer/9687', '/sports/baseball/roster/michael-chiaravallo/9692', '/sports/baseball/roster/andrew-swenson/9691', '/sports/baseball/roster/nic-adamo/9666', '/sports/baseball/roster/brady-swenson/9686', '/sports/baseball/roster/luke-nascimento/9693', '/sports/baseball/roster/dylan-radtke/9699', '/sports/baseball/roster/ben-sinins/9685', '/sports/baseball/roster/bryce-reimer/9684', '/sports/baseball/roster/ethan-firestein/9673', '/sports/baseball/roster/ryan-facinelli/9672', '/sports/baseball/roster/grant-voytovich/9689']
# []
# base_url: http://www.gobulldogs.com
# https://www.gobulldogs.com/sports/baseball/roster/2024
# ...
# []
# base_url: https://usfdons.com/index.aspx
# https://usfdons.com/index.aspx/sports/baseball/roster/2024
# []
# []
# base_url: http://www.sjsuspartans.com
# 404 Error
# 404 Error
# https://www.sjsuspartans.com/sports/baseball/roster/
# ['/sports/baseball/roster/season/2024/player/tyler-albanese', '/sports/baseball/roster/season/2024/player/dalton-bowling', '/sports/baseball/roster/season/2024/player/timmy-reeve', '/sports/baseball/roster/season/2024/player/jesse-gutierrez', '/sports/baseball/roster/season/2024/player/matt-spear', '/sports/baseball/roster/season/2024/player/micky-thompson', '/sports/baseball/roster/season/2024/player/zach-griffin', '/sports/baseball/roster/season/2024/player/caden-duke', '/sports/baseball/roster/#', '/sports/baseball/roster/season/2024/player/kyle-scritzky', '/sports/baseball/roster/season/2024/player/jeriah-lewis', '/sports/baseball/roster/season/2024/player/corey-sanchez', '/sports/baseball/roster/season/2024/player/jeremiah-odum', '/sports/baseball/roster/season/2024/player/michael-rice', '/sports/baseball/roster/season/2024/player/jaden-onaca', '/sports/baseball/roster/season/2024/player/robert-hamchuk', '/sports/baseball/roster/season/2024/player/joey-cammarata', '/sports/baseball/roster/season/2024/staff/josh-pike', '/sports/baseball/roster/season/2024/player/neil-jansen', '/sports/baseball/roster/season/2024/player/nik-trapani', '/sports/baseball/roster/season/2024/player/jackson-forbes', '/sports/baseball/roster/season/2024/player/ej-barnes', '/sports/baseball/roster/season/2024/player/gary-hall', '/sports/baseball/roster/season/2024/player/sebastian-orduno', '/sports/baseball/roster/season/2024/staff/brad-sanfilippo', '/sports/baseball/roster/season/2024/player/casey-spencer', '/sports/baseball/roster/season/2024/player/trent-keys', '/sports/baseball/roster/season/2024/player/tj-khela', '/sports/baseball/roster/season/2024/player/cody-ferrante', '/sports/baseball/roster/season/2024/staff/thomas-walker', '/sports/baseball/roster/season/2024/player/hunter-dorraugh', '/sports/baseball/roster/season/2024/player/drew-stapleton', '/sports/baseball/roster/season/2024/player/cole-ehrhorn', '/sports/baseball/roster/season/2024/player/keaton-chase', '/sports/baseball/roster/season/2024/player/jake-maroney', '/sports/baseball/roster/season/2024/player/ethan-ross', '/sports/baseball/roster/season/2024/player/theo-hardy', '/sports/baseball/roster/season/2024/player/jared-lewis', '/sports/baseball/roster/season/2024/player/jacob-campagna', '/sports/baseball/roster/season/2024/player/cade-cushing', '/sports/baseball/roster/season/2024/player/cade-van-allen', '/sports/baseball/roster/season/2024/player/kimo-fukofuka', '/sports/baseball/roster/season/2024/player/trey-brooks', '/sports/baseball/roster/season/2024/player/nolan-george', '/sports/baseball/roster/season/2024/player/nathan-cadena']
# []
# base_url: http://www.shupirates.com
# https://www.shupirates.com/sports/baseball/roster/2024
# ["/sports/baseball/roster/pat-d'amico/7161", '/sports/baseball/roster/carter-kelsey/7153', '/sports/baseball/roster/jake-walman/7165', '/sports/baseball/roster/jackson-balzan/7168', '/sports/baseball/roster/colin-dowlen/7143', '/sports/baseball/roster/staus-pokrovsky/7156', '/sports/baseball/roster/jay-allmer/7139', '/sports/baseball/roster/ryan-reich/7157', '/sports/baseball/roster/devin-hack/7150', '/sports/baseball/roster/andrew-bianco/7170', '/sports/baseball/roster/frankie-scrivanic/7173', '/sports/baseball/roster/alex-nicolosi/7155', '/sports/baseball/roster/nate-espelin/7178', '/sports/baseball/roster/jonathan-luders/7154', '/sports/baseball/roster/john-downing/7144', '/sports/baseball/roster/aiden-robbins/7175', '/sports/baseball/roster/cody-sharman/7181', '/sports/baseball/roster/kyle-lyons/7169', '/sports/baseball/roster/cole-zak/7171', '/sports/baseball/roster/nick-ferri/7146', '/sports/baseball/roster/zack-sylvester/7158', '/sports/baseball/roster/jack-wentworth/7160', '/sports/baseball/roster/michael-gillen/7148', '/sports/baseball/roster/richie-cimpric/7141', '/sports/baseball/roster/kevin-milewski/7179', "/sports/baseball/roster/alex-d'ambrosio/7167", '/sports/baseball/roster/casey-cumiskey/7164', '/sports/baseball/roster/jayson-torres/7172', '/sports/baseball/roster/gabe-cavazzoni/7174', '/sports/baseball/roster/daniel-frontera/7147', '/sports/baseball/roster/joey-calabretti/7180', '/sports/baseball/roster/justin-ford/7166', '/sports/baseball/roster/danny-melnick/7163', '/sports/baseball/roster/ryan-frontera/7162', '/sports/baseball/roster/anthony-ehly/7145', '/sports/baseball/roster/max-viera/7159', '/sports/baseball/roster/dane-hoggard/7152', '/sports/baseball/roster/cole-hansen/7151', '/sports/baseball/roster/nick-bisaccia/7140', '/sports/baseball/roster/eric-wert/7176']
# []
# base_url: http://gamecocksonline.com
# 404 Error
# 404 Error
# https://gamecocksonline.com/sports/baseball/roster/
# ['/sports/wten/roster/', '/sports/baseball/roster/player/dylan-eskew/', '/sports/baseball/roster/player/austin-brinling/', '/sports/baseball/roster/player/will-tippett/', '/sports/baseball/roster/player/ricky-williams/', '/sports/baseball/roster/player/dalton-reeves/', '/sports/baseball/roster/player/tristan-salinas/', '/sports/baseball/roster/player/david-cromer/', '/sports/bvball/roster/', '/sports/track/roster/', '/sports/baseball/roster/player/joey-wittig/', '/sports/baseball/roster/player/garrett-gainey/', '/sports/baseball/roster/player/lee-ellis/', '/sports/baseball/roster/player/parker-marlatt/', '/sports/baseball/roster/player/edward-copper/', '/sports/baseball/roster/player/cole-messina/', '/sports/baseball/roster/player/ryan-bakes/', '/sports/baseball/roster/coach/monte-lee/', '/sports/mbball/roster/', '/sports/baseball/roster/player/tyler-causey/', '/sports/baseball/roster/player/sam-simpson-2/', '/sports/baseball/roster/player/jordan-carrion/', '/sports/baseball/roster/player/roman-kimball/', '/sports/baseball/roster/player/jackson-phipps/', '/sports/baseball/roster/player/tyler-zedalis/', '/sports/baseball/roster/player/talmadge-lecroy/', '/sports/baseball/roster/player/ty-good/', '/sports/baseball/roster/player/eli-jerzembeck/', '/sports/baseball/roster/player/eli-jones/', '/sports/baseball/roster/coach/mike-current/', '/sports/wbball/roster/', '/sports/baseball/roster/player/drake-quinn/', '/sports/baseball/roster/coach/ryan-west/', '/sports/baseball/roster/coach/lt-tolbert-coach/', '/sports/wgolf/roster/', '/sports/baseball/roster/coach/mark-kingston/', '/sports/baseball/roster/player/evan-stone/', '/sports/baseball/roster/player/ethan-petry/', '/sports/baseball/roster/coach/matt-williams-2/', '/sports/softball/roster/', '/sports/wsoc/roster/', '/sports/baseball/roster/player/jevarra-martin/', '/sports/football/roster/', '/sports/baseball/roster/player/connor-mccreery/', '/sports/baseball/roster/player/austin-williamson/', '/sports/baseball/roster/player/jake-mccoy/', '/sports/baseball/roster/coach/joey-holcomb/', '/sports/baseball/roster/player/parker-noland/', '/sports/baseball/roster/player/reese-marcum/', '/sports/baseball/roster/player/kennedy-jones/', '/sports/baseball/roster/player/carson-hornung/', '/sports/baseball/roster/player/chris-veach/', '/sports/baseball/roster/player/tyler-dean/', '/sports/baseball/roster/player/blake-jackson/', '/sports/baseball/roster/player/gavin-casas/', '/sports/mten/roster/', '/sports/mgolf/roster/', '/sports/equestrian/roster/', '/sports/baseball/roster/player/michael-polk/', '/sports/swimming/roster/', '/sports/wvball/roster/', '/sports/msoc/roster/', '/sports/baseball/roster/player/tyler-pitzer/', '/sports/baseball/roster/player/xavier-pelzer/', '/sports/wcross/roster/', '/sports/baseball/roster/player/matthew-becker-2/', '/sports/baseball/roster/', '/sports/baseball/roster/player/dylan-brewer/']
# []
# base_url: http://www.siusalukis.com/
# https://www.siusalukis.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/alec-nigut/8152', '/sports/baseball/roster/andrew-yusypchuk/8162', '/sports/baseball/roster/al-holguin/8165', '/sports/baseball/roster/jake-combs/8129', '/sports/baseball/roster/sam-myers/8164', '/sports/baseball/roster/kade-coombe/8161', '/sports/baseball/roster/mathieu-vallee/8145', '/sports/baseball/roster/jordan-bach/8166', '/sports/baseball/roster/ben-riffe/8142', '/sports/baseball/roster/cole-christman/8128', '/sports/baseball/roster/matt-schark/8143', '/sports/baseball/roster/cade-carter/8127', '/sports/baseball/roster/cade-nelis/8149', '/sports/baseball/roster/tanner-gerdes/8168', '/sports/baseball/roster/steven-loden/8704', '/sports/baseball/roster/shane-wilhelm/8146', '/sports/baseball/roster/anthony-pron/8167', '/sports/baseball/roster/bennett-eltoft/8132', '/sports/baseball/roster/easton-dermody/8131', '/sports/baseball/roster/jackson-mccoy/8163', '/sports/baseball/roster/justin-keuss/8150', '/sports/baseball/roster/aidan-foeller/8159', '/sports/baseball/roster/jaxon-holder/8147', '/sports/baseball/roster/jake-allgeyer/8158', '/sports/baseball/roster/scott-harper/8134', '/sports/baseball/roster/hesston-gray/8160', '/sports/baseball/roster/cole-yearsley/8156', '/sports/baseball/roster/anthony-kodama/8148', '/sports/baseball/roster/nathan-bandy/8124', '/sports/baseball/roster/trey-cutchen/8155', '/sports/baseball/roster/ryan-birr/8151', '/sports/baseball/roster/tyler-leroy/8153', '/sports/baseball/roster/cole-koonce/8169', '/sports/baseball/roster/oliver-parizek/8154', '/sports/baseball/roster/mike-hansell/8133']
# []
# base_url: http://www.southernmiss.com
# https://www.southernmiss.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/chase-adams/9351', '/sports/baseball/roster/billy-butler/9492', '/sports/baseball/roster/mccarty-english/9499', '/sports/baseball/roster/lawson-odom/9481', '/sports/baseball/roster/will-armistead/9354', '/sports/baseball/roster/brady-faust/9360', '/sports/baseball/roster/ben%20riley-flowers/9496', '/sports/baseball/roster/chandler-best/9355', '/sports/baseball/roster/seth-smith/9479', '/sports/baseball/roster/davis-gillespie/9361', '/sports/baseball/roster/jb-middleton/9365', '/sports/baseball/roster/drew-druckenmiller/9495', '/sports/baseball/roster/sawyer-toney/9489', '/sports/baseball/roster/dalton-mcintyre/9482', '/sports/baseball/roster/eli-collins/9488', '/sports/baseball/roster/tucker-stockman/9373', '/sports/baseball/roster/gray-bane/9500', '/sports/baseball/roster/cole-boswell/9486', '/sports/baseball/roster/jackson-parker/9369', '/sports/baseball/roster/jacob-keys/9483', '/sports/baseball/roster/cal-culpepper/9485', '/sports/baseball/roster/jw-armistead/9494', '/sports/baseball/roster/matthew-adams/9352', '/sports/baseball/roster/matthew-russo/9371', '/sports/baseball/roster/peyton-lacy/9498', '/sports/baseball/roster/nick-monistere/9366', '/sports/baseball/roster/jake-cook/9356', '/sports/baseball/roster/ozzie-pratt/9480', '/sports/baseball/roster/graham-crawford/9357', '/sports/baseball/roster/niko-mazza/9364', '/sports/baseball/roster/colby-allen/9353', '/sports/baseball/roster/landen-payne/9497', '/sports/baseball/roster/gabe-broadus/9487', '/sports/baseball/roster/josh-och/9490', '/sports/baseball/roster/slade-wilks/9375', '/sports/baseball/roster/nolan-tucker/9484', '/sports/baseball/roster/carson-paetow/9368', '/sports/baseball/roster/drake-meeks/9493', '/sports/baseball/roster/kros-sivley/9372', '/sports/baseball/roster/braden-luke/9363', '/sports/baseball/roster/billy-oldham/9367']
# []
# base_url: http://www.ragincajuns.com
# https://www.ragincajuns.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/john-taylor/9373', '/sports/baseball/roster/duncan-pastore/9383', '/sports/baseball/roster/clayton-pourciau/9382', '/sports/baseball/roster/carson-fluno/9365', '/sports/baseball/roster/bryan-broussard,%20jr./9379', '/sports/baseball/roster/jr-tollett/9398', '/sports/baseball/roster/drew-kirby/9395', '/sports/baseball/roster/blake-marshall/9368', '/sports/baseball/roster/ben-robichaux/9371', '/sports/baseball/roster/jt-etheridge/9364', '/sports/baseball/roster/trey-lafleur/9367', '/sports/baseball/roster/lee-amedee/9360', '/sports/baseball/roster/patrick-vienne/9386', '/sports/baseball/roster/dylan-theut/9374', '/sports/baseball/roster/steven-cash/9361', '/sports/baseball/roster/josh-alexander/9380', '/sports/baseball/roster/kyle-debarge/9363', '/sports/baseball/roster/tate-hess/9389', '/sports/baseball/roster/clay-wargo/9375', '/sports/baseball/roster/connor-cuff/9384', '/sports/baseball/roster/maddox-mandino/9378', '/sports/baseball/roster/lp-langevin/9397', '/sports/baseball/roster/murphy-brooks/9396', '/sports/baseball/roster/jackson-halter/9388', '/sports/baseball/roster/andrew-herrmann/9392', '/sports/baseball/roster/jack-martinez/9385', '/sports/baseball/roster/phil-brennaman/9391', '/sports/baseball/roster/conor-higgs/9366', '/sports/baseball/roster/luke-yuhasz/9376', '/sports/baseball/roster/blake-mcgehee/9369', '/sports/baseball/roster/colton-ryals/9381', '/sports/baseball/roster/brendan-moody/9370', '/sports/baseball/roster/zach-storbakken/9387', '/sports/baseball/roster/mason-zambo/9377', '/sports/baseball/roster/chase-morgan/9400', '/sports/baseball/roster/matthew-holzhammer/9390', '/sports/baseball/roster/jose-torres/9399', '/sports/baseball/roster/caleb-stelly/9372', '/sports/baseball/roster/david-christie/9362', '/sports/baseball/roster/riley-marcotte/9394']
# []
# base_url: http://SFAjacks.com
# https://SFAjacks.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/kade-parker/5601', '/sports/baseball/roster/caleb-cude/5592', '/sports/baseball/roster/will-larson/5602', '/sports/baseball/roster/bryce-yosko/5575', '/sports/baseball/roster/lawson-moreno/5597', '/sports/baseball/roster/dylan-savino/5576', '/sports/baseball/roster/brock-knoerr/5577', '/sports/baseball/roster/cody-ausmus/5610', '/sports/baseball/roster/dylan-bourgeios/5565', '/sports/baseball/roster/caleb-garcia-rameau/5606', '/sports/baseball/roster/reid-bowyer/5574', '/sports/baseball/roster/alex-gomez/5582', '/sports/baseball/roster/colton-griffin/5563', '/sports/baseball/roster/zerick-warren/5588', '/sports/baseball/roster/cade-stapleton/5599', '/sports/baseball/roster/reid-boyett/5573', '/sports/baseball/roster/carter-hines/5596', '/sports/baseball/roster/cody-fleischer/5580', '/sports/baseball/roster/sam-adams/5589', '/sports/baseball/roster/jack-james/5583', '/sports/baseball/roster/garrett-landry/5581', '/sports/baseball/roster/caleb-rutledge/5590', '/sports/baseball/roster/trent-nickerson/5591', '/sports/baseball/roster/julian-thompson/5569', '/sports/baseball/roster/will-dixon/5561', '/sports/baseball/roster/tyree-carr/5567', '/sports/baseball/roster/cole-hill/5584', '/sports/baseball/roster/tom-biggs/5562', '/sports/baseball/roster/cal-martin/5568', '/sports/baseball/roster/crew-wilson/5593', '/sports/baseball/roster/conner-woods/5579', '/sports/baseball/roster/cody-smith/5586', '/sports/baseball/roster/peyton-parker/5578', '/sports/baseball/roster/elian-balmaceda/5585', '/sports/baseball/roster/hunter-prescher/5604', '/sports/baseball/roster/nolan-brown/5564', '/sports/baseball/roster/dylan-mulcahy/5608', '/sports/baseball/roster/andrew-kithil/5609', '/sports/baseball/roster/skyler-jaco/5571']
# []
# base_url: http://www.TTUsports.com/
# 404 Error
# 404 Error
# 404 Error
# 404 Error
# 404 Error
# 404 Error
# skipped roster b/c roster page had no soup
# base_url: http://www.utsports.com
# https://www.utsports.com/sports/baseball/roster/2024
# ['/sports/baseball/roster/2024?print=true']
# []
# base_url: http://www.stonehillskyhawks.com
# 404 Error
# 404 Error
# 404 Error
# 404 Error
# 404 Error
# 404 Error
# skipped roster b/c roster page had no soup
# Time taken: 170.62044596672058 seconds

# %%
skipped_rosters_df = pd.DataFrame(skipped_rosters)
skipped_players_df = pd.DataFrame(skipped_players)

# %%
player_bio_df.to_csv(f"test_data/all_player_bios_3_13.csv", index=False)
skipped_rosters_df.to_csv('test_data/all_skipped_rosters_3_13.csv', index=False)
skipped_players_df.to_csv('test_data/all_skipped_players_3_13.csv', index=False)

# %%
##SCRAPE SINGLE ROSTER FOR ALL PLAYER BIO LINKS AND DOWNLOAD PLAYER BIO DATA INTO DATAFRAME

school_url = 'https://goheels.com/'
with Session() as s:
    r = s.get(school_url+'/sports/baseball/roster'+year, headers=_HEADERS)
if r.status_code == 403:
    print('An error occurred with the GET Request')
    print('403 Error: blocked request')
soup = BeautifulSoup(r.text, features='lxml')

player_urls = []

# Initialize an empty DataFrame with all possible column names to collect roster data
# all_possible_columns = ['Name', 'Jersey Number', 'Social Media', 'Class', 'Position', 'Bat/Throw', 'B/T','Ht./Wt.', 'Hometown', 'High School','Major', 'Height','Weight','Year']
df = pd.DataFrame()

for div in soup.find_all('div', {'class': 'sidearm-roster-player-image'}):
    a = div.find('a')
    player_bio_url = a['href']
    print(f" Retrieving roster information from: {player_bio_url}")
    
    with Session() as s:
        r = s.get(school_url+'/sports/baseball/roster', headers=_HEADERS)
    if r.status_code == 403:
        print('An error occurred with the GET Request')
        print('403 Error: blocked request')
    soup = BeautifulSoup(r.text, features='lxml')

    #START RETRIEVING DATA FROM PLAYER BIO WEBPAGE
    try:
        name_span = soup.find('span', {'class': 'sidearm-roster-player-name'})
        
        # Try to find the first name span
        first_name_span = name_span.find('span', {'class': 'sidearm-roster-player-first-name'})
        if first_name_span is not None:
            first_name = first_name_span.text
        else:
            # Try something else if the first name span doesn't exist
            spans = name_span.find_all('span')
            first_name = spans[0].text if spans else ''
        
        # Try to find the last name span
        last_name_span = name_span.find('span', {'class': 'sidearm-roster-player-last-name'})
        if last_name_span is not None:
            last_name = last_name_span.text
        else:
            # Try something else if the last name span doesn't exist
            spans = name_span.find_all('span')
            last_name = spans[1].text if len(spans) > 1 else ''
        
        name = f"{first_name} {last_name}"

    except AttributeError:
        name = ''  # Handle missing name
    
    # Get jersey number
    try:
        jersey_number_span = soup.find('span', {'class': 'sidearm-roster-player-jersey-number'})
        jersey_number = jersey_number_span.text.strip()
    except AttributeError:
        jersey_number = ''  # Handle missing jersey number
    
    # Get player attributes
    ul = soup.find('ul', {'class': 'flex flex-item-1 row flex-wrap'})
    dl_tags = ul.find_all('dl')
    headers = [tag.find('dt').text.rstrip(':') for tag in dl_tags]  # Remove colons
    # print(f"headers: {headers}")
    data = [tag.find('dd').text for tag in dl_tags]
    
    # Get social media link
    try:
        social_media_div = soup.find('div', {'class': 'sidearm-roster-player-social flex flex-wrap'})
        if social_media_div is not None:
            social_media_a = social_media_div.find('a', {'class': 'sidearm-roster-player-social-link'})
            if social_media_a is not None:
                social_media_link = social_media_a['href']
            else:
                social_media_link = ''  # Handle missing social media a tag
        else:
            social_media_link = ''  # Handle missing social media div
    except KeyError:
        social_media_link = ''  # Handle missing href attribute
    
    
    # Add name, jersey number, and social media link to the list of headers and data
    headers = ['Name', 'Jersey Number', 'Social Media'] + headers
    data = [name, jersey_number, social_media_link] + data
    
    # Create a dictionary with the player's data
    player_data = {'Name': name, 'Jersey Number': jersey_number, 'Social Media': social_media_link}
    player_data.update(dict(zip(headers, data)))
    
    # Convert the dictionary to a DataFrame
    player_df = pd.DataFrame([player_data])
    
    # Append the player's data to the DataFrame
    df = pd.concat([df, player_df], ignore_index=True, sort=False)
    
    # print(df.columns)
    print(df)
    # break #Temporarily only loop once to get all types of fields and different html structures


# # print(player_urls)

# %%
#SCRAPE SINGLE PLAYER BIO PAGE

from bs4 import BeautifulSoup
import pandas as pd
from requests import Session

# Your player bio URL
player_bio_url = 'https://clariongoldeneagles.com/sports/baseball/roster/kasey-shughart/9657'

# Initialize an empty DataFrame with all possible column names
all_possible_columns = ['Name', 'Jersey Number', 'Social Media', 'Class', 'Position', 'Bat/Throw', 'B/T','Ht./Wt.', 'Hometown', 'High School','Major', 'Height','Weight','Year']
player_bio_df = pd.DataFrame(columns=all_possible_columns)

# Create a session
with Session() as s:
    # Send a GET request to the player bio URL
    r = s.get(player_bio_url, headers=_HEADERS)

# Check the status code of the response
if r.status_code == 403:
    print('An error occurred with the GET Request')
    print('403 Error: blocked request')

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(r.text, 'lxml')
# print(soup)

##__________________ GET PLAYER NAME

#START RETRIEVING DATA FROM PLAYER BIO WEBPAGE
 # Get player name
try:
    name_span = soup.find('span', {'class': 'sidearm-roster-player-name'})
    
    # Try to find the first name span
    first_name_span = name_span.find('span', {'class': 'sidearm-roster-player-first-name'})
    if first_name_span is not None:
        first_name = first_name_span.text
    else:
        # Try something else if the first name span doesn't exist
        spans = name_span.find_all('span')
        first_name = spans[0].text if spans else ''
    
    # Try to find the last name span
    last_name_span = name_span.find('span', {'class': 'sidearm-roster-player-last-name'})
    if last_name_span is not None:
        last_name = last_name_span.text
    else:
        # Try something else if the last name span doesn't exist
        spans = name_span.find_all('span')
        last_name = spans[1].text if len(spans) > 1 else ''
    
    name = f"{first_name} {last_name}"

except AttributeError:
    name = ''  # Handle missing name

# Get jersey number
try:
    jersey_number_span = soup.find('span', {'class': 'sidearm-roster-player-jersey-number'})
    jersey_number = jersey_number_span.text.strip()
except AttributeError:
    jersey_number = ''  # Handle missing jersey number

# Get player attributes
try:
    ul = soup.find('ul', {'class': 'flex flex-item-1 row flex-wrap'})
    dl_tags = ul.find_all('dl')
    headers = [tag.find('dt').text.rstrip(':') for tag in dl_tags]  # Remove colons
    # print(f"headers: {headers}")
    data = [tag.find('dd').text for tag in dl_tags]
except AttributeError:
    data = '' #Handle missing player bio info
# Get social media link
try:
    social_media_div = soup.find('div', {'class': 'sidearm-roster-player-social flex flex-wrap'})
    if social_media_div is not None:
        social_media_a = social_media_div.find('a', {'class': 'sidearm-roster-player-social-link'})
        if social_media_a is not None:
            social_media_link = social_media_a['href']
        else:
            social_media_link = ''  # Handle missing social media a tag
    else:
        social_media_link = ''  # Handle missing social media div
except KeyError:
    social_media_link = ''  # Handle missing href attribute


# Add name, jersey number, and social media link to the list of headers and data
# headers = ['Name', 'Jersey Number', 'Social Media'] + headers
# data = [name, jersey_number, social_media_link] + data

# Create a dictionary with the player's data
player_data = {'Name': name, 'Jersey Number': jersey_number, 'Social Media': social_media_link}
player_data.update(dict(zip(headers, data)))

# Convert the dictionary to a DataFrame
player_df = pd.DataFrame([player_data])

# Append the player's data to the DataFrame
player_bio_df = pd.concat([player_bio_df, player_df], ignore_index=True, sort=False)

# print(df.columns)
print(player_bio_df)
## NEED TO FIGURE OUT HOW TO COMBINE ROSTER STATS FROM TABLES THAT DON:T HAVE LIKE COLUMNS BUT WILL HAVE OVERLAPPING COLUMNS SOMEWHAT

# %%
#SCRAPE INDIVIDUAL PLAYER BIO LINK/PAGE

# %%
print(player_bio_df['Name'])

# %%
official_websites.to_csv(f"data/all_schools_and_media_links_w_roster_urls.csv", index=False)

# %%
print(official_websites)
